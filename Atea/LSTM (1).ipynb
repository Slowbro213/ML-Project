# %%
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from category_encoders import TargetEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# --- Utility Functions ---
def preprocess_target(y, clip_percentile=99.0):
    y_clipped = np.clip(y, 1e-6, np.percentile(y, clip_percentile))
    return np.log1p(y_clipped)

def inverse_preprocess_target(y): return np.expm1(y)

def cyclical_encode_month(df, col='mp_month'):
    df[f'{col}_sin'] = np.sin(2 * np.pi * (df[col] - 1) / 12)
    df[f'{col}_cos'] = np.cos(2 * np.pi * (df[col] - 1) / 12)
    return df

def remove_outliers(df, column='mp_price', iqr_multiplier=1.0):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - iqr_multiplier * IQR
    upper = Q3 + iqr_multiplier * IQR
    return df[(df[column] >= lower) & (df[column] <= upper)].reset_index(drop=True)

# --- Load & Preprocess Full Dataset ---
df = pd.read_csv("wfp_food_prices_database.csv", low_memory=False)
df = df.drop(columns=["mp_commoditysource", "adm0_name", "adm1_name", "mkt_name", "cur_name", "pt_name", "um_name"], errors='ignore')
df = df[df["mp_price"] > 0].reset_index(drop=True)
df = remove_outliers(df, column='mp_price')
df = cyclical_encode_month(df, col='mp_month')
df["adm1_mean_price"] = df.groupby("adm1_id")["mp_price"].transform("mean")
for col in ["adm1_id", "cm_id", "cur_id", "pt_id", "um_id"]:
    df[col] = df[col].astype(str)

X = df[[
    "adm1_id", "cm_id", "cm_name", "cur_id", "pt_id", "um_id",
    "mp_month_sin", "mp_month_cos", "mp_year", "adm1_mean_price"
]]
y = preprocess_target(df["mp_price"])

categorical = X.select_dtypes(include=["object"]).columns.tolist()
numerical = X.select_dtypes(include=["int64", "float64"]).columns.tolist()

preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numerical),
    ("cat", TargetEncoder(min_samples_leaf=5, smoothing=10.0), categorical)
])

X_processed = preprocessor.fit_transform(X, y)
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)
X_train_lstm = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# --- Build and Train Final LSTM ---
model = Sequential([
    Input(shape=(1, X_train.shape[1])),
    LSTM(32, activation='tanh'),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.001), loss="mse")

early_stop = EarlyStopping(patience=5, restore_best_weights=True)

start_time = time.time()
history = model.fit(
    X_train_lstm, y_train,
    validation_split=0.1,
    epochs=50,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
training_time = time.time() - start_time
print(f"\n⏱ Training time: {training_time:.2f} seconds")

# --- Evaluate on Test Set ---
y_pred = model.predict(X_test_lstm).flatten()
y_pred_orig = inverse_preprocess_target(y_pred)
y_test_orig = inverse_preprocess_target(y_test)

test_mae = np.mean(np.abs(y_pred_orig - y_test_orig))
test_rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred_orig))
test_r2 = r2_score(y_test_orig, y_pred_orig)

print("\n📊 Test Results:")
print(f"Test MAE: {test_mae:.2f}")
print(f"Test RMSE: {test_rmse:.2f}")
print(f"Test R²: {test_r2:.4f}")

# --- Visualizations ---
# Residual Plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test_orig, y_pred_orig - y_test_orig, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("True Price")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# Predicted vs Actual
plt.figure(figsize=(8, 6))
plt.scatter(y_test_orig, y_pred_orig, alpha=0.5)
plt.plot([y_test_orig.min(), y_test_orig.max()], [y_test_orig.min(), y_test_orig.max()], 'r--')
plt.xlabel("True Price")
plt.ylabel("Predicted Price")
plt.title("Predicted vs Actual Prices")
plt.show()
# Out:
# Epoch 1/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 1.8363 - val_loss: 0.1000
# Epoch 2/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0966 - val_loss: 0.0914
# Epoch 3/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0894 - val_loss: 0.0881
# Epoch 4/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0866 - val_loss: 0.0885
# Epoch 5/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0873 - val_loss: 0.0867
# Epoch 6/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0851 - val_loss: 0.0851
# Epoch 7/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0849 - val_loss: 0.0847
# Epoch 8/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0840 - val_loss: 0.0845
# Epoch 9/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0826 - val_loss: 0.0828
# Epoch 10/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0839 - val_loss: 0.0858
# Epoch 11/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0816 - val_loss: 0.0823
# Epoch 12/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0810 - val_loss: 0.0806
# Epoch 13/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0793 - val_loss: 0.0926
# Epoch 14/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0808 - val_loss: 0.0802
# Epoch 15/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0808 - val_loss: 0.0816
# Epoch 16/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0801 - val_loss: 0.0785
# Epoch 17/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0791 - val_loss: 0.0785
# Epoch 18/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0788 - val_loss: 0.0789
# Epoch 19/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0775 - val_loss: 0.0776
# Epoch 20/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0780 - val_loss: 0.0784
# Epoch 21/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0783 - val_loss: 0.0801
# Epoch 22/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0768 - val_loss: 0.0758
# Epoch 23/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0774 - val_loss: 0.0760
# Epoch 24/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0760 - val_loss: 0.0754
# Epoch 25/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0771 - val_loss: 0.0752
# Epoch 26/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0751 - val_loss: 0.0750
# Epoch 27/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0751 - val_loss: 0.0759
# Epoch 28/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0742 - val_loss: 0.0753
# Epoch 29/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0744 - val_loss: 0.0755
# Epoch 30/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0733 - val_loss: 0.0747
# Epoch 31/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0752 - val_loss: 0.0756
# Epoch 32/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0726 - val_loss: 0.0740
# Epoch 33/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0738 - val_loss: 0.0733
# Epoch 34/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0740 - val_loss: 0.0748
# Epoch 35/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0737 - val_loss: 0.0725
# Epoch 36/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0735 - val_loss: 0.0721
# Epoch 37/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0729 - val_loss: 0.0784
# Epoch 38/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0722 - val_loss: 0.0712
# Epoch 39/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0725 - val_loss: 0.0728
# Epoch 40/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0725 - val_loss: 0.0738
# Epoch 41/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0729 - val_loss: 0.0783
# Epoch 42/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0716 - val_loss: 0.0727
# Epoch 43/50
# 2861/2861 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0719 - val_loss: 0.0766
#
# ⏱ Training time: 420.52 seconds
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
#
# 📊 Test Results:
# Test MAE: 10.44
# Test RMSE: 16.72
# Test R²: 0.8825

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.15.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.8.1
